# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("D:/Projects/EduDrop-Student-DropOut-Analysis/Algorithms & Analysis/assets/data.csv")

# %%
df.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
df.isna().sum()
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance\t                      0
# Previous qualification                            0
# Previous qualification (grade)                    0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Admission grade                                   0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# ...

# %%
df.describe()
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     4424.000000       4424.000000        4424.000000  4424.000000
# mean         1.178571         18.669078           1.727848  8856.642631
# std          0.605747         17.484682           1.313793  2063.566416
# min          1.000000          1.000000           0.000000    33.000000
# 25%          1.000000          1.000000           1.000000  9085.000000
# 50%          1.000000         17.000000           1.000000  9238.000000
# 75%          1.000000         39.000000           2.000000  9556.000000
# max          6.000000         57.000000           9.000000  9991.000000
#
#        Daytime/evening attendance\t  Previous qualification  \
# count                   4424.000000             4424.000000
# mean                       0.890823                4.577758
# std                        0.311897               10.216592
# min                        0.000000                1.000000
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder
lbl = LabelEncoder()

# %%
df['Target'] = lbl.fit_transform(df['Target'])

# %%
correlational_matrix = df.corr()
correlational_matrix
# Out:
#                                                 Marital status  \
# Marital status                                        1.000000
# Application mode                                      0.264006
# Application order                                    -0.125854
# Course                                                0.046365
# Daytime/evening attendance\t                         -0.274939
# Previous qualification                                0.062529
# Previous qualification (grade)                       -0.022406
# Nacionality                                          -0.008843
# Mother's qualification                                0.193163
# Father's qualification                                0.130353
# Mother's occupation                                   0.034994
# Father's occupation                                   0.031609
# Admission grade                                      -0.004771
# Displaced                                            -0.234886
# ...

# %%
target_correlation = correlational_matrix['Target']

# %%
selectedcols = target_correlation[target_correlation > 0.1].index.tolist()

# %%
df = df[selectedcols]

# %%
df.head()
# Out:
#    Previous qualification (grade)  Admission grade  Displaced  \
# 0                           122.0            127.3          1
# 1                           160.0            142.5          1
# 2                           122.0            124.8          1
# 3                           122.0            119.6          1
# 4                           100.0            141.5          0
#
#    Tuition fees up to date  Scholarship holder  \
# 0                        1                   0
# 1                        0                   0
# 2                        0                   0
# 3                        1                   0
# 4                        1                   0
#
#    Curricular units 1st sem (enrolled)  Curricular units 1st sem (approved)  \
# 0                                    0                                    0
# 1                                    6                                    6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Previous qualification (grade)       4424 non-null   float64
#  1   Admission grade                      4424 non-null   float64
#  2   Displaced                            4424 non-null   int64
#  3   Tuition fees up to date              4424 non-null   int64
#  4   Scholarship holder                   4424 non-null   int64
#  5   Curricular units 1st sem (enrolled)  4424 non-null   int64
#  6   Curricular units 1st sem (approved)  4424 non-null   int64
#  7   Curricular units 1st sem (grade)     4424 non-null   float64
#  8   Curricular units 2nd sem (enrolled)  4424 non-null   int64
#  9   Curricular units 2nd sem (approved)  4424 non-null   int64
#  10  Curricular units 2nd sem (grade)     4424 non-null   float64
# ...

# %%
import seaborn as sns
sns.boxplot(df)
# Out:
# <Axes: >

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

# %%
mask = ~((df < Q1 - 1.5 * IQR) | (df > Q3 + 1.5 * IQR))
df = df[mask]

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df.isna().sum()
# Out:
# Previous qualification (grade)          179
# Admission grade                          86
# Displaced                                 0
# Tuition fees up to date                 528
# Scholarship holder                     1099
# Curricular units 1st sem (enrolled)     424
# Curricular units 1st sem (approved)     180
# Curricular units 1st sem (grade)        726
# Curricular units 2nd sem (enrolled)     369
# Curricular units 2nd sem (approved)      44
# Curricular units 2nd sem (grade)        877
# Target                                    0
# dtype: int64

# %%
df = df.fillna(df.median())

# %%
df.isna().sum()
# Out:
# Previous qualification (grade)         0
# Admission grade                        0
# Displaced                              0
# Tuition fees up to date                0
# Scholarship holder                     0
# Curricular units 1st sem (enrolled)    0
# Curricular units 1st sem (approved)    0
# Curricular units 1st sem (grade)       0
# Curricular units 2nd sem (enrolled)    0
# Curricular units 2nd sem (approved)    0
# Curricular units 2nd sem (grade)       0
# Target                                 0
# dtype: int64

# %%
X = df.drop('Target' , axis = 1)
y = df['Target']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
Xtrain , Xtest , ytrain , ytest = train_test_split(X , y , test_size = 0.2 , random_state = 48)

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 48)

# %%
XStrain , ystrain = sm.fit_resample(Xtrain , ytrain)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
lr.fit(Xtrain , ytrain)
# Out:
# LogisticRegression()

# %%
lr.score(Xtrain , ytrain)
# Out:
# 0.7270415371573891

# %%
lr.score(Xtest , ytest)
# Out:
# 0.7197740112994351

# %%
from sklearn.svm import SVC
svc = SVC()

# %%
svc.fit(Xtrain , ytrain)
# Out:
# SVC()

# %%
svc.score(Xtrain , ytrain)
# Out:
# 0.7586888951681265

# %%
svc.score(Xtest , ytest)
# Out:
# 0.7310734463276836

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(max_depth=5)

# %%
dt.fit(Xtrain , ytrain)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
dt.score(Xtrain , ytrain)
# Out:
# 0.74936422718282

# %%
dt.score(Xtest , ytest)
# Out:
# 0.7209039548022599

# %%
from sklearn.neighbors import KNeighborsClassifier
kc = KNeighborsClassifier()

# %%
kc.fit(Xtrain , ytrain)
# Out:
# KNeighborsClassifier()

# %%
kc.score(Xtrain , ytrain)
# Out:
# 0.7781859282283131

# %%
kc.score(Xtest , ytest)
# Out:
# 0.711864406779661

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=100 , max_depth=5 , class_weight='balanced')

# %%
rfc.fit(Xtrain , ytrain)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=5)

# %%
rfc.score(Xtrain , ytrain)
# Out:
# 0.7216727889234247

# %%
rfc.score(Xtest , ytest)
# Out:
# 0.7062146892655368

# %%
ypred = rfc.predict(Xtest)

# %%
rfc = RandomForestClassifier(class_weight={0: 1, 1: 1, 2: 1} , max_depth= 10,
 min_samples_leaf= 4,
 min_samples_split= 2,
 n_estimators = 50)
rfc.fit(Xtrain , ytrain)
# Out:
# RandomForestClassifier(class_weight={0: 1, 1: 1, 2: 1}, max_depth=10,
#                        min_samples_leaf=4, n_estimators=50)

# %%
rfc.score(Xtrain , ytrain)
# Out:
# 0.8194405199208816

# %%
rfc.score(Xtest , ytest)
# Out:
# 0.735593220338983

# %%
from sklearn.model_selection import cross_val_score , KFold
num_folds = 5
kf = KFold(n_splits=num_folds)

# %%
cross_val_results = cross_val_score(rfc , X , y , cv = kf)

# %%
print(cross_val_results)
print(cross_val_results.mean())
# Out:
# [0.71299435 0.74011299 0.6960452  0.70847458 0.73190045]
# 0.7179055142265511

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier(learning_rate = 0.5 , max_depth = 6 , min_child_weight = 0.5 , gamma = 0)

# %%
xgb.fit(Xtrain , ytrain)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.5, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=0.5, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
xgb.score(Xtrain , ytrain)
# Out:
# 0.9937835546764623

# %%
xgb.score(Xtest , ytest)
# Out:
# 0.7242937853107345

# %%
from sklearn.ensemble import AdaBoostClassifier
ada = AdaBoostClassifier(algorithm='SAMME')

# %%
ada.fit(Xtrain , ytrain)
# Out:
# AdaBoostClassifier(algorithm='SAMME')

# %%
ada.score(Xtrain , ytrain)
# Out:
# 0.7188471319581803

# %%
ada.score(Xtest , ytest)
# Out:
# 0.7141242937853107

# %%
from sklearn.metrics import classification_report , confusion_matrix
confusion = confusion_matrix(ytest , ypred)
report = classification_report(ytest , ypred)

# %%
print(confusion)
# Out:
# [[170  81  32]
#  [ 19  89  53]
#  [ 18  57 366]]

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.60      0.69       283
#            1       0.39      0.55      0.46       161
#            2       0.81      0.83      0.82       441
#
#     accuracy                           0.71       885
#    macro avg       0.67      0.66      0.66       885
# weighted avg       0.74      0.71      0.71       885

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(activation='relu' , solver= 'sgd' , hidden_layer_sizes=20 , max_iter = 1000 , learning_rate='adaptive')

# %%
mlp.fit(Xtrain , ytrain)
mlp.score(Xtrain , ytrain)
# Out:
# 0.7349533766600734

# %%
mlp.score(Xtest , ytest)
# Out:
# 0.7265536723163842
